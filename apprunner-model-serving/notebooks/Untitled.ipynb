# %%
from haystack.utils import clean_wiki_text, convert_files_to_dicts, fetch_archive_from_http, print_answers
from haystack.nodes import FARMReader, TransformersReader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 from haystack.utils import clean_wiki_text, convert_files_to_dicts, fetch_archive_from_http, print_answers
#       2 from haystack.nodes import FARMReader, TransformersReader
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/__init__.py:7, in <module>
#       4 logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", datefmt="%m/%d/%Y %H:%M:%S", level=logging.WARNING)
#       5 logging.getLogger("haystack").setLevel(logging.INFO)
# ----> 7 from haystack import pipelines
#       8 from haystack.schema import Document, Answer, Label, MultiLabel, Span
#       9 from haystack.nodes import BaseComponent
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/pipelines/__init__.py:1, in <module>
# ----> 1 from haystack.pipelines.base import Pipeline, RootNode, RayPipeline
#       2 from haystack.pipelines.standard_pipelines import (
#       3     BaseStandardPipeline,
#       4     DocumentSearchPipeline,
#    (...)
#      13     FAQPipeline,
#      14 )
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/pipelines/base.py:16, in <module>
#      14 from networkx import DiGraph
#      15 from networkx.drawing.nx_agraph import to_agraph
# ---> 16 from haystack.nodes.evaluator.evaluator import calculate_em_str_multi, calculate_f1_str_multi, semantic_answer_similarity
#      18 try:
#      19     from ray import serve
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/nodes/__init__.py:2, in <module>
#       1 from haystack.nodes.base import BaseComponent
# ----> 2 from haystack.nodes.answer_generator import BaseGenerator, RAGenerator, Seq2SeqGenerator
#       3 from haystack.nodes.connector import Crawler
#       4 from haystack.nodes.document_classifier import BaseDocumentClassifier, TransformersDocumentClassifier
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/nodes/answer_generator/__init__.py:2, in <module>
#       1 from haystack.nodes.answer_generator.base import BaseGenerator
# ----> 2 from haystack.nodes.answer_generator.transformers import RAGenerator, Seq2SeqGenerator
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/nodes/answer_generator/transformers.py:14, in <module>
#      12 from haystack.schema import Answer, Document
#      13 from haystack.nodes.answer_generator.base import BaseGenerator
# ---> 14 from haystack.nodes.retriever.dense import DensePassageRetriever
#      17 logger = logging.getLogger(__name__)
#      20 class RAGeneratorType(Enum):
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/nodes/retriever/__init__.py:1, in <module>
# ----> 1 from haystack.nodes.retriever.base import BaseRetriever
#       2 from haystack.nodes.retriever.dense import DensePassageRetriever, EmbeddingRetriever, TableTextRetriever
#       3 from haystack.nodes.retriever.sparse import ElasticsearchRetriever, ElasticsearchFilterOnlyRetriever, TfidfRetriever
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/nodes/retriever/base.py:12, in <module>
#      10 from haystack.schema import Document, MultiLabel
#      11 from haystack.nodes.base import BaseComponent
# ---> 12 from haystack.document_stores.base import BaseDocumentStore, BaseKnowledgeGraph
#      15 logger = logging.getLogger(__name__)
#      18 class BaseGraphRetriever(BaseComponent):
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/document_stores/__init__.py:11, in <module>
#       9     from haystack.document_stores.milvus2x import Milvus2DocumentStore as MilvusDocumentStore
#      10 else:
# ---> 11     from haystack.document_stores.milvus import MilvusDocumentStore  # type: ignore
#      13 from haystack.document_stores.sql import SQLDocumentStore
#      14 from haystack.document_stores.weaviate import WeaviateDocumentStore
#
# File ~/workspace/aws-samples/apprunner-model-serving/venv/lib/python3.9/site-packages/haystack/document_stores/milvus.py:12, in <module>
#       9 from tqdm import tqdm
#      10 from scipy.special import expit
# ---> 12 from milvus import IndexType, MetricType, Milvus, Status
#      14 from haystack.schema import Document
#      15 from haystack.document_stores.sql import SQLDocumentStore
#
# ModuleNotFoundError: No module named 'milvus'

# %%
# In-Memory Document Store
from haystack.document_stores import InMemoryDocumentStore

document_store = InMemoryDocumentStore()
